# %% [markdown]
# # VAERS - COVID19
# The idea of the current notebook is to assess the veracity of the data presented in https://www.openvaers.com/covid-data
# OpenVAERS website is not affiliated to neither https://vaers.hhs.gov nor https://wonder.cdc.gov, where VAERS data can be downloaded and explored, respectively.

# %% [markdown]
# ## Filesystem cleanup

# %%
# %sh mkdir -p /tmp/datasets/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sh rm -rf /tmp/datasets/*
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Dataset preparation

# %% [markdown]
# **Get dataset**
# Manually download the 2020, 2021 and NonDomestic zip files from https://vaers.hhs.gov/data/datasets.html (the website has a captcha system)
# Inside it can also be found the **VAERS Data User Guide**, in case you want to know more about the datasets that are going to be used in this notebook.
#
# Upload the files to `dbfs:/FileStore/` so they can later be accessed from Databricks cluster.

# %%
# %fs ls /FileStore/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/2020VAERSData.zip</td><td>2020VAERSData.zip</td><td>11393690</td></tr><tr><td>dbfs:/FileStore/2021VAERSData.zip</td><td>2021VAERSData.zip</td><td>89300030</td></tr><tr><td>dbfs:/FileStore/NonDomesticVAERSData.zip</td><td>NonDomesticVAERSData.zip</td><td>56636236</td></tr><tr><td>dbfs:/FileStore/import-stage/</td><td>import-stage/</td><td>0</td></tr><tr><td>dbfs:/FileStore/plots/</td><td>plots/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/</td><td>tables/</td><td>0</td></tr></tbody></table></div>

# %%
dbutils.fs.cp("dbfs:/FileStore/2020VAERSData.zip", "file:/tmp/datasets/2020VAERSData.zip")
dbutils.fs.cp("dbfs:/FileStore/2021VAERSData.zip", "file:/tmp/datasets/2021VAERSData.zip")
dbutils.fs.cp("dbfs:/FileStore/NonDomesticVAERSData.zip", "file:/tmp/datasets/NonDomesticVAERSData.zip")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>

# %%
# %sh 
unzip /tmp/datasets/2020VAERSData.zip -d /tmp/datasets/
unzip /tmp/datasets/2021VAERSData.zip -d /tmp/datasets/
unzip /tmp/datasets/NonDomesticVAERSData.zip -d /tmp/datasets/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Archive:  /tmp/datasets/2020VAERSData.zip
#   inflating: /tmp/datasets/2020VAERSDATA.csv
#   inflating: /tmp/datasets/2020VAERSSYMPTOMS.csv
#   inflating: /tmp/datasets/2020VAERSVAX.csv
# Archive:  /tmp/datasets/2021VAERSData.zip
#   inflating: /tmp/datasets/2021VAERSDATA.csv
#   inflating: /tmp/datasets/2021VAERSSYMPTOMS.csv
#   inflating: /tmp/datasets/2021VAERSVAX.csv
# Archive:  /tmp/datasets/NonDomesticVAERSData.zip
#   inflating: /tmp/datasets/NonDomesticVAERSDATA.csv
#   inflating: /tmp/datasets/NonDomesticVAERSSYMPTOMS.csv
#   inflating: /tmp/datasets/NonDomesticVAERSVAX.csv
# </div>

# %%
# %sh ls -lhR /tmp/datasets
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/tmp/datasets:
# total 795M
# -rw-r--r-- 1 root root  41M Jul  4 17:05 2020VAERSDATA.csv
# -rw-r--r-- 1 root root  11M Jul 13 14:10 2020VAERSData.zip
# -rw-r--r-- 1 root root 4.5M Jul  4 17:05 2020VAERSSYMPTOMS.csv
# -rw-r--r-- 1 root root 4.4M Jul  4 17:05 2020VAERSVAX.csv
# -rw-r--r-- 1 root root 267M Jul  4 17:06 2021VAERSDATA.csv
# -rw-r--r-- 1 root root  86M Jul 13 14:10 2021VAERSData.zip
# -rw-r--r-- 1 root root  41M Jul  4 17:06 2021VAERSSYMPTOMS.csv
# -rw-r--r-- 1 root root  30M Jul  4 17:06 2021VAERSVAX.csv
# -rw-r--r-- 1 root root 230M Jul  4 17:07 NonDomesticVAERSDATA.csv
# -rw-r--r-- 1 root root  55M Jul 13 14:10 NonDomesticVAERSData.zip
# -rw-r--r-- 1 root root  18M Jul  4 17:07 NonDomesticVAERSSYMPTOMS.csv
# -rw-r--r-- 1 root root  12M Jul  4 17:07 NonDomesticVAERSVAX.csv
# </div>

# %%
# %sh wc -l /tmp/datasets/*.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">    49413 /tmp/datasets/2020VAERSDATA.csv
#     60672 /tmp/datasets/2020VAERSSYMPTOMS.csv
#     59237 /tmp/datasets/2020VAERSVAX.csv
#    406002 /tmp/datasets/2021VAERSDATA.csv
#    542932 /tmp/datasets/2021VAERSSYMPTOMS.csv
#    420982 /tmp/datasets/2021VAERSVAX.csv
#    124523 /tmp/datasets/NonDomesticVAERSDATA.csv
#    199100 /tmp/datasets/NonDomesticVAERSSYMPTOMS.csv
#    169917 /tmp/datasets/NonDomesticVAERSVAX.csv
#   2032778 total
# </div>

# %%
# %sh head -n2 /tmp/datasets/2021*.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">==&gt; /tmp/datasets/2021VAERSDATA.csv &lt;==
# VAERS_ID,RECVDATE,STATE,AGE_YRS,CAGE_YR,CAGE_MO,SEX,RPT_DATE,SYMPTOM_TEXT,DIED,DATEDIED,L_THREAT,ER_VISIT,HOSPITAL,HOSPDAYS,X_STAY,DISABLE,RECOVD,VAX_DATE,ONSET_DATE,NUMDAYS,LAB_DATA,V_ADMINBY,V_FUNDBY,OTHER_MEDS,CUR_ILL,HISTORY,PRIOR_VAX,SPLTTYPE,FORM_VERS,TODAYS_DATE,BIRTH_DEFECT,OFC_VISIT,ER_ED_VISIT,ALLERGIES
# 0916600,01/01/2021,TX,33.0,33,,F,,Right side of epiglottis swelled up and hinder swallowing pictures taken Benadryl Tylenol taken,,,,,,,,,Y,12/28/2020,12/30/2020,2,None,PVT,,None,None,None,,,2,01/01/2021,,Y,,Pcn and bee venom
#
# ==&gt; /tmp/datasets/2021VAERSSYMPTOMS.csv &lt;==
# VAERS_ID,SYMPTOM1,SYMPTOMVERSION1,SYMPTOM2,SYMPTOMVERSION2,SYMPTOM3,SYMPTOMVERSION3,SYMPTOM4,SYMPTOMVERSION4,SYMPTOM5,SYMPTOMVERSION5
# 0916600,Dysphagia,23.10,Epiglottitis,23.10,,,,,,
#
# ==&gt; /tmp/datasets/2021VAERSVAX.csv &lt;==
# VAERS_ID,VAX_TYPE,VAX_MANU,VAX_LOT,VAX_DOSE_SERIES,VAX_ROUTE,VAX_SITE,VAX_NAME
# 0916600,COVID19,MODERNA,037K20A,1,IM,LA,COVID19 (COVID19 (MODERNA))
# </div>

# %% [markdown]
# **DataFrames and SQL views creation**

# %%
vaers_data = spark.read.csv("file:/tmp/datasets/*VAERSDATA.csv",
                     header='true',
                     sep=",",
                     escape='"',
                     dateFormat='MM-dd-yyyy',
                     timestampFormat='MM-dd-yyyy HH:mm:ss',
                     inferSchema='true')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vaers_data.createOrReplaceTempView("vaers_data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vaers_symptoms = spark.read.csv("file:/tmp/datasets/*VAERSSYMPTOMS.csv",
                     header='true',
                     sep=",",
                     escape='"',
                     dateFormat='MM-dd-yyyy',
                     timestampFormat='MM-dd-yyyy HH:mm:ss',
                     inferSchema='true')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vaers_symptoms.createOrReplaceTempView("vaers_symptoms")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vaers_vax = spark.read.csv("file:/tmp/datasets/*VAERSVAX.csv",
                     header='true',
                     sep=",",
                     escape='"',
                     dateFormat='MM-dd-yyyy',
                     timestampFormat='MM-dd-yyyy HH:mm:ss',
                     inferSchema='true') \
                     .where("vax_type = 'COVID19'") \
                     .select("VAERS_ID", "VAX_MANU", "VAX_NAME")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# 451398 instead of 650133 (59236 + 420981 + 169916) from original files, which means that 198735 entries were not COVID19 vaccines.
vaers_vax.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 451398</div>

# %%
# We will use DISTINCT to remove some strange duplicates, like the one below, which has the highest number of duplicates:
display(vaers_vax.filter("vaers_id = 1215401"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VAERS_ID</th><th>VAX_MANU</th><th>VAX_NAME</th></tr></thead><tbody><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1215401</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr></tbody></table></div>

# %%
# And now from 451398 to 438828, which means that 12570 entries were duplicates.
vaers_vax = vaers_vax.distinct()
vaers_vax.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: 438828</div>

# %%
vaers_vax.createOrReplaceTempView("vaers_vax")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now an usual task would be to do some data wrangling to avoid `null` values, but since we don't know whether the user forgot to indicate some parameter or assumed that `null` already implied a negative value, we can't say for sure.
# Therefore, we will use `null` values as they were originally designed in databases, that is, as something unknown or undetermined.

# %%
# %sql CREATE OR REPLACE TEMPORARY VIEW V_VAERS_FULL_DATA AS
SELECT 
  v.vax_manu, 
  d.vaers_id, d.recvdate, d.vax_date, d.age_yrs, d.sex, d.hospdays, d.disable, d.recovd, d.died, d.datedied, d.symptom_text
FROM vaers_data d
  JOIN vaers_vax v on d.vaers_id = v.vaers_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql --Same number as in VAERSVAX dataset, which means we didn't add up extra rows from the join with VAERSDATA dataset.
select count(*) from V_VAERS_FULL_DATA
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>438828</td></tr></tbody></table></div>

# %% [markdown]
# ## Analysis 1 - Reports per vaccine

# %%
# %sql select distinct(vax_manu) from vaers_vax
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vax_manu</th></tr></thead><tbody><tr><td>MODERNA</td></tr><tr><td>JANSSEN</td></tr><tr><td>UNKNOWN MANUFACTURER</td></tr><tr><td>PFIZER\BIONTECH</td></tr></tbody></table></div>

# %%
# %sql select vax_manu, count(*) as reports
from vaers_vax
group by vax_manu
order by reports desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vax_manu</th><th>reports</th></tr></thead><tbody><tr><td>PFIZER\BIONTECH</td><td>208870</td></tr><tr><td>MODERNA</td><td>186532</td></tr><tr><td>JANSSEN</td><td>42359</td></tr><tr><td>UNKNOWN MANUFACTURER</td><td>1067</td></tr></tbody></table></div>

# %% [markdown]
# ## Analysis 2 - Most common symptoms

# %%
# %sql CREATE OR REPLACE TEMPORARY VIEW V_ALL_SYMPTOMS AS
select v.vax_manu, v.vaers_id,
       s.symptom1, s.symptom2, s.symptom3, s.symptom4, s.symptom5
from vaers_vax v
join vaers_symptoms s
  on v.vaers_id = s.vaers_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# It could happen that one report includes more than 5 symptoms, and that means that multiple rows could be included in Symptoms table for the same report.

# %%
# %sql select * from V_ALL_SYMPTOMS
where vaers_id = 916691
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vax_manu</th><th>vaers_id</th><th>symptom1</th><th>symptom2</th><th>symptom3</th><th>symptom4</th><th>symptom5</th></tr></thead><tbody><tr><td>MODERNA</td><td>916691</td><td>Chills</td><td>Dizziness</td><td>Headache</td><td>Injection site pain</td><td>Nausea</td></tr><tr><td>MODERNA</td><td>916691</td><td>Productive cough</td><td>null</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# In order to do a proper analysis to all the symptoms, it would be easier if we had all of them in a single column, and for that we can use `stack` function:

# %%
# %sql CREATE OR REPLACE TEMPORARY VIEW V_ALL_SYMPTOMS_STACK AS
select * from (
  SELECT vax_manu, vaers_id,
    stack(5, symptom1, symptom2, symptom3, symptom4, symptom5) as symptom
  FROM V_ALL_SYMPTOMS
  )
where symptom is not null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql select * from V_ALL_SYMPTOMS_STACK 
where vaers_id = 916691
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vax_manu</th><th>vaers_id</th><th>symptom</th></tr></thead><tbody><tr><td>MODERNA</td><td>916691</td><td>Chills</td></tr><tr><td>MODERNA</td><td>916691</td><td>Dizziness</td></tr><tr><td>MODERNA</td><td>916691</td><td>Headache</td></tr><tr><td>MODERNA</td><td>916691</td><td>Injection site pain</td></tr><tr><td>MODERNA</td><td>916691</td><td>Nausea</td></tr><tr><td>MODERNA</td><td>916691</td><td>Productive cough</td></tr></tbody></table></div>

# %% [markdown]
# Let's see now the most common symptoms for all 3 manufacturers separatedly, and using different output styles.

# %%
# %sql 
select vax_manu, symptom, count(*) as reports 
from V_ALL_SYMPTOMS_STACK
where vax_manu = 'MODERNA'
group by vax_manu, symptom
order by reports desc
limit 50
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vax_manu</th><th>symptom</th><th>reports</th></tr></thead><tbody><tr><td>MODERNA</td><td>Headache</td><td>35673</td></tr><tr><td>MODERNA</td><td>Pyrexia</td><td>31665</td></tr><tr><td>MODERNA</td><td>Fatigue</td><td>29631</td></tr><tr><td>MODERNA</td><td>Chills</td><td>29486</td></tr><tr><td>MODERNA</td><td>Pain</td><td>28164</td></tr><tr><td>MODERNA</td><td>Nausea</td><td>21124</td></tr><tr><td>MODERNA</td><td>Injection site erythema</td><td>19842</td></tr><tr><td>MODERNA</td><td>Injection site pain</td><td>19234</td></tr><tr><td>MODERNA</td><td>Pain in extremity</td><td>19056</td></tr><tr><td>MODERNA</td><td>Dizziness</td><td>18745</td></tr><tr><td>MODERNA</td><td>Injection site swelling</td><td>15336</td></tr><tr><td>MODERNA</td><td>Injection site pruritus</td><td>14906</td></tr><tr><td>MODERNA</td><td>Pruritus</td><td>12379</td></tr><tr><td>MODERNA</td><td>Rash</td><td>11794</td></tr><tr><td>MODERNA</td><td>Arthralgia</td><td>11564</td></tr><tr><td>MODERNA</td><td>Myalgia</td><td>11480</td></
><tr><td>PFIZER\BIONTECH</td><td>Flushing</td><td>3850</td></tr><tr><td>PFIZER\BIONTECH</td><td>Electrocardiogram</td><td>3833</td></tr><tr><td>PFIZER\BIONTECH</td><td>Peripheral swelling</td><td>3709</td></tr><tr><td>PFIZER\BIONTECH</td><td>Loss of consciousness</td><td>3647</td></tr><tr><td>PFIZER\BIONTECH</td><td>Neck pain</td><td>3350</td></tr><tr><td>PFIZER\BIONTECH</td><td>Decreased appetite</td><td>3166</td></tr><tr><td>PFIZER\BIONTECH</td><td>Paraesthesia oral</td><td>3104</td></tr><tr><td>PFIZER\BIONTECH</td><td>Condition aggravated</td><td>3019</td></tr></tbody></table></div>

# %%
# %sql 
select vax_manu, symptom, count(*) as reports 
from V_ALL_SYMPTOMS_STACK
where vax_manu = 'JANSSEN'
group by vax_manu, symptom
having reports > 1000
order by reports desc
limit 50
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vax_manu</th><th>symptom</th><th>reports</th></tr></thead><tbody><tr><td>JANSSEN</td><td>Headache</td><td>12493</td></tr><tr><td>JANSSEN</td><td>Pyrexia</td><td>10408</td></tr><tr><td>JANSSEN</td><td>Chills</td><td>9419</td></tr><tr><td>JANSSEN</td><td>Pain</td><td>8333</td></tr><tr><td>JANSSEN</td><td>Fatigue</td><td>8300</td></tr><tr><td>JANSSEN</td><td>Dizziness</td><td>6491</td></tr><tr><td>JANSSEN</td><td>Nausea</td><td>6469</td></tr><tr><td>JANSSEN</td><td>Pain in extremity</td><td>4569</td></tr><tr><td>JANSSEN</td><td>Myalgia</td><td>3282</td></tr><tr><td>JANSSEN</td><td>Injection site pain</td><td>2808</td></tr><tr><td>JANSSEN</td><td>Hyperhidrosis</td><td>2676</td></tr><tr><td>JANSSEN</td><td>Dyspnoea</td><td>2567</td></tr><tr><td>JANSSEN</td><td>Arthralgia</td><td>2527</td></tr><tr><td>JANSSEN</td><td>Vomiting</td><td>2383</td></tr><tr><td>JANSSEN</td><td>Asthenia</td><td>2064</td></tr><tr><td>JANSSEN</td><td>Syncope</td><td>1806</td></tr><tr><td>JANSSEN</td><td>Rash</td><td>1698</td></tr><tr><td>JANSSEN</td><td>Feeling abnormal</td><td>1660</td></tr><tr><td>JANSSEN</td><td>Diarrhoea</td><td>1540</td></tr><tr><td>JANSSEN</td><td>Tremor</td><td>1487</td></tr><tr><td>JANSSEN</td><td>Hypoaesthesia</td><td>1456</td></tr><tr><td>JANSSEN</td><td>Paraesthesia</td><td>1432</td></tr><tr><td>JANSSEN</td><td>Loss of consciousness</td><td>1336</td></tr><tr><td>JANSSEN</td><td>Malaise</td><td>1328</td></tr><tr><td>JANSSEN</td><td>Chest pain</td><td>1226</td></tr><tr><td>JANSSEN</td><td>Back pain</td><td>1186</td></tr><tr><td>JANSSEN</td><td>Body temperature</td><td>1142</td></tr><tr><td>JANSSEN</td><td>Pruritus</td><td>1114</td></tr><tr><td>JANSSEN</td><td>Blood test</td><td>1047</td></tr><tr><td>JANSSEN</td><td>Feeling hot</td><td>1001</td></tr></tbody></table></div>

# %% [markdown]
# ## Analysis 3 - Number of deaths

# %%
# %sql --Strange cases in which the same report has different vaccines, probably due to faulty data.
select vaers_id, count(*) as cases
from V_VAERS_FULL_DATA
where died = 'Y'
group by vaers_id
having cases > 1
order by cases desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vaers_id</th><th>cases</th></tr></thead><tbody><tr><td>1358087</td><td>3</td></tr><tr><td>1207198</td><td>2</td></tr><tr><td>1433471</td><td>2</td></tr><tr><td>1345770</td><td>2</td></tr></tbody></table></div>

# %%
# %sql 
select * 
from vaers_vax 
where vaers_id in (1358087, 1207198, 1433471, 1345770) 
order by vaers_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VAERS_ID</th><th>VAX_MANU</th><th>VAX_NAME</th></tr></thead><tbody><tr><td>1207198</td><td>PFIZER\BIONTECH</td><td>COVID19 (COVID19 (PFIZER-BIONTECH))</td></tr><tr><td>1207198</td><td>MODERNA</td><td>COVID19 (COVID19 (MODERNA))</td></tr><tr><td>1345770</td><td>UNKNOWN MANUFACTURER</td><td>COVID19 (COVID19 (UNKNOWN))</td></tr><tr><td>1345770</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1358087</td><td>JANSSEN</td><td>COVID19 (COVID19 (JANSSEN))</td></tr><tr><td>1358087</td><td>PFIZER\BIONTECH</td><td>COVID19 (COVID19 (PFIZER-BIONTECH))</td></tr><tr><td>1358087</td><td>MODERNA</td><td>COVID19 (COVID19 (MODERNA))</td></tr><tr><td>1433471</td><td>MODERNA</td><td>COVID19 (COVID19 (MODERNA))</td></tr><tr><td>1433471</td><td>PFIZER\BIONTECH</td><td>COVID19 (COVID19 (PFIZER-BIONTECH))</td></tr></tbody></table></div>

# %%
# %sql select vax_manu, count(*) as cases
from V_VAERS_FULL_DATA
where died = 'Y'
group by vax_manu
order by cases desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vax_manu</th><th>cases</th></tr></thead><tbody><tr><td>PFIZER\BIONTECH</td><td>5814</td></tr><tr><td>MODERNA</td><td>2687</td></tr><tr><td>JANSSEN</td><td>523</td></tr><tr><td>UNKNOWN MANUFACTURER</td><td>29</td></tr></tbody></table></div>

# %%
# %sql 
select substring(age_range, 3) as age_range, count(*) as cases 
from (
  select case
     when age_yrs < 18 then '1. Under 18'
     when age_yrs between 18 and 29 then '2. 18-29'
     when age_yrs between 30 and 49 then '3. 30-49'
     when age_yrs between 50 and 59 then '4. 50-59'
     when age_yrs between 60 and 69 then '5. 60-69'
     when age_yrs between 70 and 79 then '6. 70-79'
     when age_yrs between 80 and 89 then '7. 80-89'
     when age_yrs > 90 then '8. 90 and over'
     else '9. Undetermined'
     end as age_range
  from V_VAERS_FULL_DATA
  where died = 'Y'
  )
group by age_range
order by age_range
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age_range</th><th>cases</th></tr></thead><tbody><tr><td> Under 18</td><td>17</td></tr><tr><td> 18-29</td><td>71</td></tr><tr><td> 30-49</td><td>350</td></tr><tr><td> 50-59</td><td>453</td></tr><tr><td> 60-69</td><td>1014</td></tr><tr><td> 70-79</td><td>1421</td></tr><tr><td> 80-89</td><td>1688</td></tr><tr><td> 90 and over</td><td>815</td></tr><tr><td> Undetermined</td><td>3224</td></tr></tbody></table></div>
